-- %% [markdown]
-- # HIGHWAY

-- %%
 require 'nn'
 require 'gnuplot'
 require 'svm'
 require 'optim'
 require 'nngraph'
 require 'image'

-- %%
itorch.image('highway.png')
-- Out:
-- Console does not support images
